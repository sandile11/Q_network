# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.load('rewards_180911-115917.npy')/30
#latest linear function approximator

# %%
x = np.linspace(0,arr.shape[0],arr.shape[0])*3

# %%
plt.plot(x, arr)
plt.xlabel('Number of Episodes', size='15')
plt.ylabel('Rewards', size='15')
# Out:
# Text(0,0.5,'Rewards')

# %%
arr = np.load('lfa_rewards_180914-104652.npy')*
x = np.linspace(0,arr.shape[0],arr.shape[0])*3

# %%
plt.plot(x, arr)
plt.xlabel('Number of Episodes', size='15')
plt.ylabel('Rewards', size='15')
# Out:
# Text(0,0.5,'Rewards')

# %%
## DQN 16-09-2018
arr = np.load('DQN_rewards_180916-234036.npy')*50
x = np.linspace(0,arr.shape[0],arr.shape[0])*3

# %%
plt.plot(x, arr)
plt.xlabel('Number of Episodes', size='15')
plt.ylabel('Rewards', size='15')
# Out:
# Text(0,0.5,'Rewards')

# %%
## LFA Rewards 
arr = np.load('lfa_rewards_180919-091617.npy')*50
x = np.linspace(0,arr.shape[0],arr.shape[0])*3

# %%
plt.plot(x, arr)
plt.xlabel('Number of Episodes', size='15')
plt.ylabel('Rewards', size='15')
# Out:
# Text(0,0.5,'Rewards')
